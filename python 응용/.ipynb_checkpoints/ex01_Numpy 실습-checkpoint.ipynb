# %% [markdown]
# ### 1. Numpy 사용하기

# %%
import numpy as np

# %% [markdown]
# ### numpy 객체 이해하기
# - 다차원 배열, 행렬 데이터 구조 제공
# - 동일한 자료형을 가지는 값들이 배열 형태로 존재
# - 데이터 접근을 최적화하기 위한 색인(indes)를 부여

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ####
