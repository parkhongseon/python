# %% [markdown]
# ### pandas 사용하기

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# ### pandas 객체 종류

# %%
# Series Class : 1차원 -> 인덱스(index) + 값(value)
# DataFrame Class : 2차원 -> 표와 같은 형태

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### pands 객체 다루기

# %% [markdown]
# #### 1차원 시리즈 생성

# %%
series1 = pd.Series([3,4,5])
series1
# 시리즈는 여러 값을 나열한 자료구조
# 시리즈는 index , value로 구성됨
# 데이터 프레임을 구성하는 하위 요소. 즉 시리즈가 여러 개 모이면 하나의 데이터 프레임이 됨
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
# 인덱스와 값을 가진 시리즈 생성 #1
series2 = pd.Series([3,4,5], index=['kim','seo','lee'])
series2
# Out:
# kim    3
# seo    4
# lee    5
# dtype: int64

# %%
# 인덱스와 값을 가진 시리즈 생성 #2
series3 = pd.Series({'kim':3, 'seo':4, 'lee':5})

# %% [markdown]
# #### 시리즈 속성 확인

# %%
# 값 확인 - values 
series3.values
# Out:
# array([3, 4, 5], dtype=int64)

# %%
# 인덱스 확인 - index
series3.index
# Out:
# Index(['kim', 'seo', 'lee'], dtype='object')

# %%
# 데이터 타입 확인 - dtype
series3.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### 시리즈와 인덱스의 이름 지정하기

# %%
display(series3.name) # 시리즈의 이름
display(series3.index.name) # 인덱스의 이름

# 이름 지정하기
series3.name = 'name_cnt'
series3.index.name = 'name'
display(series3.name) # 시리즈의 이름
display(series3.index.name) # 인덱스의 이름
# Out:
# None
# None
# 'name_cnt'
# 'name'

# %%
series3
# Out:
# name
# kim    3
# seo    4
# lee    5
# Name: name_cnt, dtype: int64

# %% [markdown]
# - 리스트를 이용하여 시리즈 생성하기

# %%
country_p = pd.Series([9602000, 3344000, 1488000, 2419000], index=['서울','부산','광주','대구'])
country_p.name = '2020 인구수'
country_p.index.name = '도시'

display(country_p)
# Out:
# 도시
# 서울    9602000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 시리즈 데이터 수정, 추가, 삭제

# %%
# 수정
country_p['부산'] = 3500000
country_p
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
# 추가
country_p['대전'] = 1500000
country_p
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
# 삭제 :  del, drop()
display(country_p.drop('서울'))  # pandas 시리즈 객체가 가지고 있는 내장 함수
display(country_p)               # drop을 적용하고자 할 떄는 inplace = True 로 설정

del country_p['서울'] # 파이썬 del 키워드
display(country_p)    # del 키워드는 실행과 동시에 초기화까지 됨.
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
country_p
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 2차원 데이터프레임 생성

# %%
# 단일 리스트로 데이터프레임 생성하기
num = [1, 2, 3]
df1 = pd.DataFrame(num)
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
# 컬럼명과 인덱스를 부여한 데이터프레임 생성
df2 = pd.DataFrame(num, columns=['num'], index=['f', 's', 't'])
df2
# Out:
#    num
# f    1
# s    2
# t    3

# %%
# 데이터를 이중 리스트로 넣어서 데이터프레임 생성하기
list1 = [['js-a',1],['js-b', 2],['ai',3]]
df3 = pd.DataFrame(list1, columns=['Class','Join'])
df3
# Out:
#   Class  Join
# 0  js-a     1
# 1  js-b     2
# 2    ai     3

# %%
# 데이터를 딕셔너리형으로 넣어서 데이터프레임 생성
df4 = pd.DataFrame({'Class' : ['js-a', 'js-b', 'ai'], 'Join' : [1, 2, 3]})
df4
# Out:
#   Class  Join
# 0  js-a     1
# 1  js-b     2
# 2    ai     3

# %% [markdown]
# #### 데이터프레임 속성 확인

# %%
# 값 확인 - values
df4.values
# Out:
# array([['js-a', 1],
#        ['js-b', 2],
#        ['ai', 3]], dtype=object)

# %%
# 인덱스 확인 - index
df4.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# 컬럼명 확인 - columns
df4.columns
# Out:
# Index(['Class', 'Join'], dtype='object')

# %%
# 데이터 타입 확인 - dtypes 
df4.dtypes
# Out:
# Class    object
# Join      int64
# dtype: object

# %%
person_info = pd.DataFrame({'키':[175.3, 180.2, 178.6], '몸무게' : [66.2, 78.9, 55.1],
                            '나이':[27.0, 49.0, 35.0]}, index=['son','kim','park'])
display(person_info)

person_info.T # 전치(행과 열을 바꿔줌)
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  35.0
#        son    kim   park
# 키    175.3  180.2  178.6
# 몸무게   66.2   78.9   55.1
# 나이    27.0   49.0   35.0

# %%
# 값 확인
display(person_info.values)
# 데이터 타입 확인
display(person_info.dtypes)
# 인덱스 확인
display(person_info.index)
# 컬럼명 확인
display(person_info.columns)
# Out:
# array([[175.3,  66.2,  27. ],
#        [180.2,  78.9,  49. ],
#        [178.6,  55.1,  35. ]])
# 키      float64
# 몸무게    float64
# 나이     float64
# dtype: object
# Index(['son', 'kim', 'park'], dtype='object')
# Index(['키', '몸무게', '나이'], dtype='object')

# %% [markdown]
# ### pandas 데이터 접근

# %% [markdown]
# #### 1차원 시리즈 데이터 접근

# %%
country_p
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
# 인덱스 번호로 접근
display(country_p[1]) # 광주
display(country_p[3]) # 대전
# Out:
# 1488000
# 1500000

# %%
# 인덱스 라벨 접근
display(country_p['부산'])
display(country_p['대구'])
# Out:
# 3500000
# 2419000

# %%
# 시리즈 변수에서 여러개 데이터 접근 
# 하나씩 가리키기(인덱싱)
display(country_p[['광주','대구']])
display(country_p[[1,2]])

# 슬라이싱
display(country_p['광주':'대전']) # 문자열로 슬라이싱 하면 끝값도 포함됨.마지막 값까지 접근이면 생략 가능
display(country_p[1:4]) # 마지막 값까지 접근이면 생략 가능 (인덱스 번호로 접근할 경우)
# Out:
# 도시
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64
# 도시
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64
# 도시
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64
# 도시
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 2차원 데이터프레임 열 데이터 접근

# %%
df4
# Out:
#   Class  Join
# 0  js-a     1
# 1  js-b     2
# 2    ai     3

# %%
# 인덱싱 
df4['Class'] # 시리즈 형태로 출력
# Out:
# 0    js-a
# 1    js-b
# 2      ai
# Name: Class, dtype: object

# %%
df4[['Class']] # 대괄호로 두번 감싸면 데이터프레임 형태로 출력.
# Out:
#   Class
# 0  js-a
# 1  js-b
# 2    ai

# %%
# 여러 개의 컬럼을 한꺼번에 접근(추출)하기
df4[['Class','Join']]
# Out:
#   Class  Join
# 0  js-a     1
# 1  js-b     2
# 2    ai     3

# %% [markdown]
# #### 2차원 데이터 프레임 행 데이터 접근

# %%
df6 = df4.set_index('Class') # Class 라는 컬럼을 인덱스로 사용하겠다
df6
# Out:
#        Join
# Class
# js-a      1
# js-b      2
# ai        3

# %%
# 슬라이싱으로 'js-a' 데이터 접근
df6[0 : 1] # 슬라이싱을 사용하면 행에 접근
# Out:
#        Join
# Class
# js-a      1

# %%
# js-b 꺼내오기 -> 슬라이싱으로
df6[1 : 2]
# Out:
#        Join
# Class
# js-b      2

# %%
# 인덱스 라벨을 이용하여 슬라이싱
df6['js-a' : 'js-b']
# Out:
#        Join
# Class
# js-a      1
# js-b      2

# %%
df6[:]
# Out:
#        Join
# Class
# js-a      1
# js-b      2
# ai        3

# %% [markdown]
# #### 2차원 데이터프레임 행, 열 데이터에 더 편리하게 접근하기
# - loc, iloc 인덱서
# - loc(location) : 실제로 보이는 라벨명을 통해서 데이터에 접근하는 방법
# - iloc(interger location) : numpy 배열의 인덱스 값을 통해서 데이터에 접근하는 방법, i는 interger인
#   index 번호값의 loc(위치)에 접근
# - 사용형식 :
#   데이터 변수명.인덱서[행, 열]
#   -행, 열 자리 모두 여러 개의 요소에 접근할 경우 : [요소1, 요소2, ...], 슬라이싱을 통해서도 가능

# %%
# js-b 행 데이터 접근하기
display(df6.loc['js-b']) # 인덱스 라벨
display(df6.iloc[1])
# Out:
# Join    2
# Name: js-b, dtype: int64
# Join    2
# Name: js-b, dtype: int64

# %%
# js-a 와 js-b 데이터 접근하기
display(df6.loc[:'js-b']) # 인덱스 라벨
display(df6.iloc[:2]) # 인덱스 번호
display(df6.iloc[[0, 1]])
# Out:
#        Join
# Class
# js-a      1
# js-b      2
#        Join
# Class
# js-a      1
# js-b      2
#        Join
# Class
# js-a      1
# js-b      2

# %%
# Join 열 데이터 접근하기
display(df6.loc[:, 'Join'])
display(df6.iloc[:, 0])
# Out:
# Class
# js-a    1
# js-b    2
# ai      3
# Name: Join, dtype: int64
# Class
# js-a    1
# js-b    2
# ai      3
# Name: Join, dtype: int64

# %%
# js-b의 Join 데이터 접근하기

# %%
display(df6.loc['js-b', 'Join']) # 인덱스 라벨
display(df6.iloc[1, 0])          # 인덱스 번호
# Out:
# 2
# 2

# %%
person_info
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  35.0

# %%
# 1. person_info에서 'son' 의 나이 데이터
display(person_info.iloc[0, 2])
# Out:
# 27.0

# %%
# 2. person_info에서 'son'의 키와 나이 데이터 추출
display(person_info.iloc[0, [0,2]])
person_info.iloc[0, : :2] # 슬라이싱 해서 두 개씩 띄어서 가지고 오는 규칙이 있을 경우
# Out:
# 키     175.3
# 나이     27.0
# Name: son, dtype: float64
# 키     175.3
# 나이     27.0
# Name: son, dtype: float64

# %%
# 3, person_info에서 kim, park의 몸무게, 키 순서로 데이터 추출하기
display(person_info.loc[['kim','park'],['몸무게','키']])
person_info.iloc[1:, [1, 0]]
display(person_info.loc['kim':'park', ['몸무게','키']])
display(person_info.loc['kim':, ['몸무게','키']])
# Out:
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6

# %% [markdown]
# #### 조건에 맞는 데이터 접근 : 불리언 인덱싱

# %%
df4
# Out:
#   Class  Join
# 0  js-a     1
# 1  js-b     2
# 2    ai     3

# %%
# Join 컬럼에서 값이 2 이상인 데이터 접근
df4[df4['Join' ] >= 2]
# Out:
#   Class  Join
# 1  js-b     2
# 2    ai     3

# %%
# 문자값을 기반으로 Class가 js-a 이거나 js-b인 데이터만 추출

# %%
df4[(df4['Class'] == 'js-a') | (df4['Class'] == 'js-b')]
# Out:
#   Class  Join
# 0  js-a     1
# 1  js-b     2

# %%
# Join의 컬럼 값이 2 이하인 클래스의 이름을 리스트나 배열로 출력하기
df4[df4['Join'] <= 2]['Class'].values
# Out:
# array(['js-a', 'js-b'], dtype=object)

# %%
df4.loc[df4['Join'] <= 2, 'Class'].values #loc 인덱서로 불리언 인덱싱한 값
# Out:
# array(['js-a', 'js-b'], dtype=object)

# %% [markdown]
# #### query() : 함수를 통한 행 접근
# - df4[df4['Join'] <= 2] ==> df4.query('Join <=2')
#
# - query() 장점
#   - 분석 코드가 간결
#   - 가독성 좋음
#   - 조건을 결합하여 사용하는 경우 더 강력함
# - pandas의 query 함수는 SQL의 where 함수의 역할을 함.
# - 하지만 query 는 필터링만 함. where는 조건에 따른 값을 받을 수 있음..?

# %%
# 숫자값 ==> Join의 값이 2 이상인 데이터 추출(불리언 인덱싱)
df4[df4['Join'] >= 2]
# Out:
#   Class  Join
# 1  js-b     2
# 2    ai     3

# %%
# query 함수를 사용하여 추출
df4.query('Join >= 2')
# Out:
#   Class  Join
# 1  js-b     2
# 2    ai     3

# %%
# 문자 값 ==> Class ai or js-a 데이터 추출하기
# 주의사항 : 전체조건과 추출할 문자의 따옴표 구분하기!!!!!!!!!!!
df4.query('Class == "ai" or Class == "js-a"')
# Out:
#   Class  Join
# 0  js-a     1
# 2    ai     3

# %%
# Join이 2 이하인 Class 명은 몇 개인지 확인하기 (query 함수 이용)

# 1. Join이 2 이하라는 조건에 맞는 값
df4.query('Join <= 2')
# 2. 1에서 추출한 값 []조합하여 최종 값 확인
df4.query('Join <= 2')['Class'].size
# Out:
# 2

# %%
# 인덱서 기반으로 위 문제 접근하기
df4.loc[df4['Join'] <= 2, 'Class'].size
# Out:
# 2

# %% [markdown]
# ### pandas 연산 및 유용한 함수

# %% [markdown]
# #### 파일 불러오기 및 저장

# %%
exam = pd.read_csv('./data/exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# #### 데이터 파악하기
# - head() : 앞에서부터 5개 행 출력
# - tail() : 뒤에서부터 5개 행 출력
# - shape  : 행, 열 개수 출력
# - info() : 변수 속성 출력
# - describe() : 요약 통계량 출력 --> 숫자 데이터에 대한 요약 통계량.
#                                 --> 문자 데이터를 요약통계량으로 보고자 할 경우 (include='all')

# %%
display(exam.head(3))
display(exam.tail(3))
display(exam.shape)
display(exam.info()) # 컬럼들의 속성을 보여줌 -> 모든 컬럼의 속성을 한 눈에 파악할 수 있음
# <class 'pandas.core.frame.DataFrame'> : 판다스의 데이터프레임 객체
# RangeIndex : 20 entries, 0 to 19 : 0 ~ 19 번 인덱스로 총 20개의 행 구현
# Data columns (total 5 columns) : 컬럼(변수) 개수 총 5개 구성
# # 변수 순서 
# Column : 컬럼명
# Non-Null Count : 컬럼(변수)에 들어있는 값의 개수, 결측치
# dtype : 데이터 타입
#       : int64 : 64는 변수가 64비트로 되어있다는 의미
#                   1비트(0,1)로 두 개의 값을 표현할 수 있으므로 int64 => 2^64개의 정수 표현 가능
display(exam.describe())

# 모든 변수의 요약 통계량 --> 기본적으로 숫자값들에 대한 통계정보 표시[문자값 : include='all']
# count : 빈도(frequency), 값의 개수
# mean : 평균. 모든 값을 더해서 값의 갯수로 나눈 값
# std : 표준편차(standard deviation), 변수 값들의 평균에서 떨어진 정도를 나타냄
# min : 최솟값, 가장 작은 값.
# 25% : 1사분위수(1st quantile), 하위 25%(4분의 1)지점에 위치한 값
# 50% : 중앙값(median), 하위 50%(중앙)지점에 위치한 값
# 75% : 3사분위수(3rd quantile), 하위 75%(4분의 3)지점에 위치한 값
# max : 최대값, 가장 큰 값
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
#     id  nclass  math  english  science
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58
# (20, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes
# None
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# #### 정렬
# - sort_values()

# %%
# 1차원 - 수학 컬럼을 정렬해보기 ( 내림차순으로 정렬 )
exam['math'].sort_values(ascending=False) # ascending = False => 내림차순 정렬. 기본값은 오름차순(True)
# Out:
# 7     90
# 18    89
# 17    80
# 6     80
# 19    78
# 14    75
# 16    65
# 10    65
# 1     60
# 15    58
# 9     50
# 5     50
# 0     50
# 13    48
# 12    46
# 11    45
# 2     45
# 3     30
# 4     25
# 8     20
# Name: math, dtype: int64

# %%
# 2차원 - 학생번호, 수학컬럼 내림차순 정렬
exam[['id','math']].sort_values(by='math', ascending=False).head()
# 컬럼 수가 두개 이상일 때 정렬할 기준 컬럼을 설정 => by = '기준컬럼'
# 정렬 기준 컬럼이 여러 개 일때 순서대로 입력 ==> by=['기준컬럼1', '기준컬럼2']
# Out:
#     id  math
# 7    8    90
# 18  19    89
# 17  18    80
# 6    7    80
# 19  20    78

# %% [markdown]
# #### 예제 5

# %%
data2 = pd.read_csv('./data/mpg.csv',delimiter=',')
display(data2.head(3))
display(data2.tail(3))
display(data2.shape) 
# display(data2.info()) # 속성정보를 알 수 있음.
display(data2.describe())
data2[data2['manufacturer']=="audi"].sort_values(by="hwy",ascending=False).head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 231  midsize
# 232  midsize
# 233  midsize
# (234, 11)
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 2  compact
# 3  compact
# 0  compact
# 1  compact
# 9  compact

# %% [markdown]
# ####  파생변수 만들기

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['total'] = exam[['math','english','science']].sum(axis=1)

# %%
exam[['math','english','science']].sum(axis=1)
# Out:
# 0     198
# 1     217
# 2     209
# 3     186
# 4     170
# 5     237
# 6     215
# 7     193
# 8     133
# 9     193
# 10    195
# 11    162
# 12    209
# 13    147
# 14    209
# 15    221
# 16    231
# 17    248
# 18    244
# 19    219
# dtype: int64

# %%
exam = exam.assign(mean=exam['total']/3)
exam
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
exam = exam.assign(result=np.where(exam['mean']>=60,'합격','불합격'))
#

# %%
exam
# Out:
#     id  nclass  math  english  science  total       mean result
# 0    1       1    50       98       50    198  66.000000     합격
# 1    2       1    60       97       60    217  72.333333     합격
# 2    3       1    45       86       78    209  69.666667     합격
# 3    4       1    30       98       58    186  62.000000     합격
# 4    5       2    25       80       65    170  56.666667    불합격
# 5    6       2    50       89       98    237  79.000000     합격
# 6    7       2    80       90       45    215  71.666667     합격
# 7    8       2    90       78       25    193  64.333333     합격
# 8    9       3    20       98       15    133  44.333333    불합격
# 9   10       3    50       98       45    193  64.333333     합격
# 10  11       3    65       65       65    195  65.000000     합격
# 11  12       3    45       85       32    162  54.000000    불합격
# 12  13       4    46       98       65    209  69.666667     합격
# 13  14       4    48       87       12    147  49.000000    불합격
# 14  15       4    75       56       78    209  69.666667     합격
# 15  16       4    58       98       65    221  73.666667     합격
# 16  17       5    65       68       98    231  77.000000     합격
# 17  18       5    80       78       90    248  82.666667     합격
# 18  19       5    89       68       87    244  81.333333     합격
# 19  20       5    78       83       58    219  73.000000     합격

# %% [markdown]
# ####  apply() 함수
# - 사용자 정의함수를 통해 복잡한 연산을 적용할 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def grade_check(stuRow) :
    grade = ''
    if stuRow['mean'] >= 85 :
        grade = "A"
    elif stuRow['mean'] >= 70 :
        grade = "B"
    elif stuRow['mean'] >= 60 :
        grade = "C" 
    else : 
        grade = "F"
    return grade

# %%
exam['grade'] = exam.apply(grade_check,axis=1)
display(exam.head(3))
# Out:
#    id  nclass  math  english  science  total       mean result grade
# 0   1       1    50       98       50    198  66.000000     합격     C
# 1   2       1    60       97       60    217  72.333333     합격     B
# 2   3       1    45       86       78    209  69.666667     합격     C

# %% [markdown]
# ####  group by
# - 데이터를 특정 컬럼에 맞춰 그룹화하는 함수

# %%
# 과정별 평균 구하기
exam.drop(['result','grade'], axis=1).groupby('nclass').mean()
# Out:
#           id   math  english  science   total       mean
# nclass
# 1        2.5  46.25    94.75    61.50  202.50  67.500000
# 2        6.5  61.25    84.25    58.25  203.75  67.916667
# 3       10.5  45.00    86.50    39.25  170.75  56.916667
# 4       14.5  56.75    84.75    55.00  196.50  65.500000
# 5       18.5  78.00    74.25    83.25  235.50  78.500000

# %%
exam.drop(['result','grade'], axis=1).groupby('nclass').agg('mean')
# Out:
#           id   math  english  science   total       mean
# nclass
# 1        2.5  46.25    94.75    61.50  202.50  67.500000
# 2        6.5  61.25    84.25    58.25  203.75  67.916667
# 3       10.5  45.00    86.50    39.25  170.75  56.916667
# 4       14.5  56.75    84.75    55.00  196.50  65.500000
# 5       18.5  78.00    74.25    83.25  235.50  78.500000

# %%
rs = exam.drop(['result'],axis=1).groupby(by=['nclass','grade']).mean()

# %%
# 멀티인덱스 색인
rs.loc[(2,'C')]
# Out:
# id           8.000000
# math        90.000000
# english     78.000000
# science     25.000000
# total      193.000000
# mean        64.333333
# Name: (2, C), dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
midwest = pd.read_csv('./data/midwest.csv', delimiter=',')

midwest.rename(columns={'poptotal':'total', 'popasian':'asian'},inplace=True)

midwest['전체인구 대비 아시아 인구 백분율'] = midwest['asian']/midwest['total'] * 100




midwest = midwest.assign(avg=np.where(midwest['전체인구 대비 아시아 인구 백분율'] > midwest['전체인구 대비 아시아 인구 백분율'].mean(),'large','small'))


midwest.groupby('avg').count()['PID']
# Out:
# avg
# large    119
# small    318
# Name: PID, dtype: int64

# %%
# 선생님 풀이

# %%
# m = midewst['전체인구 대비 아시아 인구 백분율'].mean()
# midwest.assign(result=np.where(midwest['전체인구 대비 아시아 인구 백분율']))

# %%
# midwest['result'].value_counts()
# midwest.groupby('result').size()

# %% [markdown]
# #### 예제7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Q1
rs = data2[['category','cty']].groupby('category').mean()

# %%
# Q2
rs.sort_values(by='cty',ascending=False)
# Out:
#                   cty
# category
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %%
# Q3
data2[['manufacturer','hwy']].groupby('manufacturer').mean().sort_values('hwy',ascending=False).head(3)
# Out:
#                     hwy
# manufacturer
# honda         32.555556
# volkswagen    29.222222
# hyundai       26.857143

# %%
# Q4
data2[['manufacturer','category']][data2['category'] == 'compact'].groupby('manufacturer').size().sort_values(ascending=False)
# Out:
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2
# dtype: int64

# %%
# loc, iloc 를 이용한 방법
# data2.loc[행, 열]
data2.loc[data2['category']=='compact', ['manufacturer','category']]
# Out:
#     manufacturer category
# 0           audi  compact
# 1           audi  compact
# 2           audi  compact
# 3           audi  compact
# 4           audi  compact
# 5           audi  compact
# 6           audi  compact
# 7           audi  compact
# 8           audi  compact
# 9           audi  compact
# 10          audi  compact
# 11          audi  compact
# 12          audi  compact
# 13          audi  compact
# 14          audi  compact
# 141       nissan  compact
# 142       nissan  compact
# 169       subaru  compact
# 170       subaru  compact
# 171       subaru  compact
# 172       subaru  compact
# 186       toyota  compact
# 187       toyota  compact
# 188       toyota  compact
# 189       toyota  compact
# 190       toyota  compact
# 191       toyota  compact
# 192       toyota  compact
# 193       toyota  compact
# 194       toyota  compact
# 195       toyota  compact
# 196       toyota  compact
# 197       toyota  compact
# 207   volkswagen  compact
# 208   volkswagen  compact
# 209   volkswagen  compact
# 210   volkswagen  compact
# 211   volkswagen  compact
# 212   volkswagen  compact
# 213   volkswagen  compact
# 214   volkswagen  compact
# 215   volkswagen  compact
# 216   volkswagen  compact
# 217   volkswagen  compact
# 218   volkswagen  compact
# 219   volkswagen  compact
# 220   volkswagen  compact

# %% [markdown]
# #### fillna - 결측치 처리

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = pd.DataFrame([['m',5.0],['f',4.0],[np.nan, 3.0],
                     ['m',4.0],['f',np.nan]],
                    columns=['gender','score'])
data
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    NaN

# %%
data['score'] = data['score'].fillna(0)

# %%
data['gender'].fillna('m',inplace=True)

# %%
data
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2      m    3.0
# 3      m    4.0
# 4      f    0.0

# %%
# 원본의 데이터가 변경되지 않음. 사용 후 원레 데이터에 덮어쓰기 작업 필요

# %% [markdown]
# #### dropna - 결측치 처리

# %%
data3 = pd.DataFrame([['m',5.0],['f',4.0],[np.nan, 3.0],
                     ['m',4.0],['f',np.nan]],
                    columns=['gender','score'])
data3
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    NaN

# %%
data3.dropna() # 결측치가 있는 행은 다 사라짐.
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0

# %%
# 결측치를 확인하는 컬럼 지정
data3.dropna(subset='score')
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0

# %% [markdown]
# #### drop - 데이터 삭제

# %%
data3.drop(2)
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0
# 4      f    NaN

# %%
data3.drop('gender',axis=1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %% [markdown]
# #### 이상치 처리
# - 정상범위에서 벗어나거나 존재할 수 없는 값
# - 삭제하거나 다른 대체값으로 변경한다.

# %%
data4 = pd.DataFrame([['m',5.0],['f',4.0],
                      ['ff',4.0],['m',4.0],
                      ['f',np.nan]],
                    columns=['gender','score'])
data4
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2     ff    4.0
# 3      m    4.0
# 4      f    NaN

# %%
data4['gender'] = np.where(data4['gender'] == 'ff', 'f', data4['gender'])

# %%
data4
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2      f    4.0
# 3      m    4.0
# 4      f    NaN

# %%
# 이 방법은 한번정도만 사용하는게 좋음. 
# 통계적인 방법으로 이상치 처리하기 -> 사분위수 활용
# 1사분위
pct25 = data2['hwy'].quantile(.25)
# 3사분위
pct75 = data2['hwy'].quantile(.75)

print(pct25, pct75)

# IQR 구하기
iqr = pct75 - pct25
print(iqr)

# 하한, 상한 경계 값 계싼
# iqr * 1.5
print("하한 경계값 :", pct25 - 1.5* iqr)
print("상한 경계값 :", pct75 + 1.5* iqr)
# Out:
# 18.0 27.0
# 9.0
# 하한 경계값 : 4.5
# 상한 경계값 : 40.5

# %%
# 이상치 제거
data2['hwy'] = np.where((data2['hwy']<4.5) | (data2['hwy']>40.5), np.nan, data2['hwy'])

# %%
data2[data2['hwy'].isnull()]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33  NaN  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35  NaN  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29  NaN  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
# 결측치 처리된 이상치를 삭제
data2.dropna(inplace=True)

# %% [markdown]
# #### cut - 카테고리(범주형) 데이터로 변경

# %%
# 일반적으로 데이터가 정해진 값 안에서 등장.
# 사용자가 임의로 사이값을 만들어 낼 수 없음 ex) 혈액형, 학점, 

# 수치형 데이터 : range가 정해져 있지 않음.

# %%
ages = [0, 2, 15, 21, 23, 37, 31, 61, 20, 41, 32, 100]
bins = [-1, 15, 25, 35, 60, 100] # 구간 정보
labels = ['미성년자','청년','중년','장년','노년']
# 미성년자 : 0 ~ 15, 청년 16~ 25, 중년 26 ~ 35, 장년 36~ 60, 노년 61 ~ 100
cats = pd.cut(ages, bins, labels=labels)

cats
# Out:
# ['미성년자', '미성년자', '미성년자', '청년', '청년', ..., '노년', '청년', '장년', '중년', '노년']
# Length: 12
# Categories (5, object): ['미성년자' < '청년' < '중년' < '장년' < '노년']

# %%
# 구간을 정해서 데이터를 묶은 다음 살펴보면 좋음.

# %%
# 10대 20대 30대 40대 50대이상
bins = [-1, 19, 29, 39, 49, 100] 
labels = ['10대','20대','30대','40대','50대이상']

cats = pd.cut(ages, bins, labels=labels)

cats
# Out:
# ['10대', '10대', '10대', '20대', '20대', ..., '50대이상', '20대', '40대', '30대', '50대이상']
# Length: 12
# Categories (5, object): ['10대' < '20대' < '30대' < '40대' < '50대이상']

# %% [markdown]
# #### concat - 데이터 병합

# %%
df1 = pd.DataFrame([[1,2,3,4,5], [60, 80, 70, 90, 85,]]).T
df1.columns = ['id', 'test']


df2 = pd.DataFrame([[1,2,3,4,5], [60, 80, 70, 90, 85,]]).T
df2.columns = ['id', 'test']

display(df1)
display(df2)

df3 = pd.concat([df1,df2])
display(df3)
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85

# %% [markdown]
# #### merge - 데이터 병합 (join 과 같은 기능 )

# %%
df4 = pd.DataFrame([[1,2,3,4,5],[60,80,70,90,85]]).T
df4.columns=['id','midterm']

df5 = pd.DataFrame([[1,2,3,4,6],[70, 83, 65, 95, 80]]).T
df5.columns=['id','final']

total = pd.merge(df4, df5, how='left', on='id')
total
# Out:
#    id  midterm  final
# 0   1       60   70.0
# 1   2       80   83.0
# 2   3       70   65.0
# 3   4       90   95.0
# 4   5       85    NaN

# %% [markdown]
# #### 데이터 로딩

# %%
# 각 동별로 인구, 공무원 수 , cctv 수
# how를 inner로 주면 교집합처럼 양쪽에 있는걸 고려해서 양쪽이

# %%
cctv = pd.read_csv('./data/광주광역시_CCTV_20230630.CSV', encoding='euc-kr') 
dong = pd.read_csv('./data/광주광역시_행정동별 현황_20211231.csv', encoding='euc-kr')

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5690 entries, 0 to 5689
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관리기관명     5690 non-null   object
#  1   소재지지번주소   5690 non-null   object
#  2   소재지도로명주소  4247 non-null   object
#  3   카메라대수     5690 non-null   int64
#  4   카메라화소     5690 non-null   object
#  5   촬영방면정보    5690 non-null   object
#  6   보관일수      5690 non-null   object
#  7   설치연도      5690 non-null   int64
#  8   위도        5680 non-null   float64
#  9   경도        5680 non-null   float64
#  10  데이터기준일자   5690 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 489.1+ KB

# %%
dong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   동  별        102 non-null    object
#  1   인구(명)       102 non-null    int64
#  2   면적(제곱킬로미터)  102 non-null    float64
#  3   세대수         102 non-null    int64
#  4   통           102 non-null    int64
#  5   리           0 non-null      float64
#  6   반           102 non-null    int64
#  7   공무원(명)      102 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 6.5+ KB

# %% [markdown]
# #### 필요 데이터 추출(전처리)

# %%
cctv.columns
# Out:
# Index(['관리기관명', '소재지지번주소', '소재지도로명주소', '카메라대수', '카메라화소', '촬영방면정보', '보관일수',
#        '설치연도', '위도', '경도', '데이터기준일자'],
#       dtype='object')

# %%
dong.columns
# Out:
# Index(['동  별', '인구(명)', '면적(제곱킬로미터)', '세대수', '통', '리', '반', '공무원(명)'], dtype='object')

# %%
cctv = cctv[["소재지지번주소","카메라대수","위도","경도"]]
dong = dong[["동  별","인구(명)","공무원(명)"]]

# %%
# 동 이름 추출
# 방법 1
def extractCCTV(row) :
    return row['소재지지번주소'].split(" ")[1]

# %%
cctv['동이름2'] = cctv.apply(extractCCTV, axis = 1)

# %%
# 방법 2
cctv['동이름3'] = cctv['소재지지번주소'].str.split(" ").str[1]

# %%
dong['동이름3']  = dong['동  별'].str.split("(").str[0]

# %%
# 두 데이터의 동이름 검색
len(set(cctv['동이름3']) & set(dong['동이름3']))
# Out:
# 37

# %%
set(cctv['동이름3']) - set(dong['동이름3'])
# Out:
# {'각화동',
#  '계림동',
#  '고룡동',
#  '광산동',
#  '구동',
#  '구소동',
#  '궁동',
#  '금곡동',
#  '금남로1가',
#  '금남로3가',
#  '금남로4가',
#  '금남로5가',
#  '금동',
#  '금호동',
#  '남동',
#  '남산동',
#  '내남동',
#  '내방동',
#  '내산동',
#  '노대동',
#  '농성동',
#  '누문동',
#  '대의동',
#  '대인동',
#  '대지동',
#  '덕림동',
#  '덕의동',
#  '덕흥동',
#  '도금동',
#  '도덕동',
#  '도천동',
#  '동산동',
#  '동호동',
#  '두암동',
#  '두정동',
#  '등임동',
#  '마륵동',
#  '망월동',
#  '매월동',
#  '명화동',
#  '문화전당로',
#  '문흥동',
#  '박호동',
#  '방림동',
#  '백서로',
#  '백운동',
#  '벽진동',
#  '복룡동',
#  '본덕동',
#  '본촌동',
#  '봉선동',
#  '북동',
#  '불로동',
#  '사동',
#  '산막동',
#  '산수동',
#  '산월동',
#  '산정동',
#  '삼거동',
#  '생용동',
#  '서동',
#  '서봉동',
#  '서석동',
#  '석정동',
#  '선교동',
#  '선동',
#  '선암동',
#  '세하동',
#  '소촌동',
#  '소태동',
#  '송대동',
#  '송산동',
#  '송정동',
#  '송촌동',
#  '송치동',
#  '송하동',
#  '송학동',
#  '수곡동',
#  '수기동',
#  '승촌동',
#  '신룡동',
#  '신장동',
#  '신촌동',
#  '쌍암동',
#  '쌍촌동',
#  '안청동',
#  '압촌동',
#  '양과동',
#  '양림로',
#  '양촌동',
#  '연산동',
#  '연제동',
#  '오룡동',
#  '오산동',
#  '오선동',
#  '오치동',
#  '옥동',
#  '용강동',
#  '용곡동',
#  '용동',
#  '용두동',
#  '용산동',
#  '용연동',
#  '용전동',
#  '운림동',
#  '운수동',
#  '운암동',
#  '운정동',
#  '원산동',
#  '월계동',
#  '월곡동',
#  '월남동',
#  '월성동',
#  '월전동',
#  '월출동',
#  '유동',
#  '유촌동',
#  '이장동',
#  '임암동',
#  '장덕동',
#  '장동',
#  '장등동',
#  '장록동',
#  '장수동',
#  '주월동',
#  '주월동1333',
#  '중흥동',
#  '지산동',
#  '지석동',
#  '지야동',
#  '지원동',
#  '지정동',
#  '지평동',
#  '진곡동',
#  '청풍동',
#  '충장로1가',
#  '충장로2가',
#  '충장로3가',
#  '충장로4가',
#  '충장로5가',
#  '충효동',
#  '칠석동',
#  '하산동',
#  '행암동',
#  '호남동',
#  '화장동',
#  '화정동',
#  '황금동',
#  '회서로11번길',
#  '회서로12번길',
#  '회서로22번길',
#  '회재로',
#  '회재로1186번길',
#  '효령동',
#  '흑석동'}

# %%
set(dong['동이름3']) - set(cctv['동이름3'])
# Out:
# {'계림1동',
#  '계림2동',
#  '광산구',
#  '금호1동',
#  '금호2동',
#  '남구',
#  '농성1동',
#  '농성2동',
#  '동곡동',
#  '동구',
#  '두암1동',
#  '두암2동',
#  '두암3동',
#  '문화동',
#  '문흥1동',
#  '문흥2동',
#  '방림1동',
#  '방림2동',
#  '백운1동',
#  '백운2동',
#  '본량동',
#  '봉선1동',
#  '봉선2동',
#  '북구',
#  '사직동',
#  '상무1동',
#  '상무2동',
#  '서구',
#  '서남동',
#  '석곡동',
#  '송암동',
#  '송정1동',
#  '송정2동',
#  '신흥동',
#  '양3동',
#  '어룡동',
#  '오치1동',
#  '오치2동',
#  '운암1동',
#  '운암2동',
#  '운암3동',
#  '월곡1동',
#  '월곡2동',
#  '월산4동',
#  '월산5동',
#  '주월2동',
#  '중앙동',
#  '중흥1동',
#  '중흥2동',
#  '중흥3동',
#  '지산1동',
#  '지산2동',
#  '지원1동',
#  '지원2동',
#  '첨단1동',
#  '첨단2동',
#  '충장동',
#  '평동',
#  '학운동',
#  '화정1동',
#  '화정2동',
#  '화정3동',
#  '화정4동',
#  '효덕동'}

# %%
# 동이름에서 숫자를 제거하고 병합하기
# 방법1
def removeNumber (row) :
    txt = row['동이름3']
    for i in range(10) :
        txt = txt.replace(str(i),"")
        
    return txt

# %%
cctv['동이름'] = cctv.apply(removeNumber, axis= 1)
dong['동이름'] = dong.apply(removeNumber, axis= 1)

# %%
len(set(cctv['동이름']) & set(dong['동이름']))
# Out:
# 52

# %%
# 방법 2 정규표현식
cctv['동이름4']=cctv['동이름3'].str.replace("\d","",regex=True)
dong['동이름4']=dong['동이름3'].str.replace("\d","",regex=True)

# %%
len(set(cctv['동이름4']) & set(dong['동이름4']))
# Out:
# 52

# %%
cctv
# Out:
#              소재지지번주소  카메라대수         위도          경도 동이름2 동이름3  동이름 동이름4
# 0      광산구 광산동 666-7      2  35.225272  126.735854  광산동  광산동  광산동  광산동
# 1     광산구 도덕동 320-15      1  35.162851  126.699911  도덕동  도덕동  도덕동  도덕동
# 2     광산구 도덕동 320-15      1  35.162851  126.699911  도덕동  도덕동  도덕동  도덕동
# 3     광산구 도산동 1128-4      4  35.127057  126.789353  도산동  도산동  도산동  도산동
# 4     광산구 도산동 1282-1      1  35.130739  126.789865  도산동  도산동  도산동  도산동
# ...              ...    ...        ...         ...  ...  ...  ...  ...
# 5685      서구 화정동 893      1  35.143405  126.881806  화정동  화정동  화정동  화정동
# 5686    북구 운암동 91-18      1  35.174489  126.879815  운암동  운암동  운암동  운암동
# 5687    북구 운암동 91-18      1  35.174489  126.879815  운암동  운암동  운암동  운암동
# 5688    북구 운암동 91-18      1  35.174489  126.879815  운암동  운암동  운암동  운암동
# 5689    서구 농성동 671-2      4        NaN         NaN  농성동  농성동  농성동  농성동
#
# [5690 rows x 8 columns]

# %%
# 결측치 제거
cctv.dropna(inplace=True)

# %%
cctv['경도'].astype('float64')
# Out:
# 0       126.735854
# 1       126.699911
# 2       126.699911
# 3       126.789353
# 4       126.789865
#            ...
# 5684    126.881806
# 5685    126.881806
# 5686    126.879815
# 5687    126.879815
# 5688    126.879815
# Name: 경도, Length: 5680, dtype: float64

# %%
# 그룹핑 후 연산 # agg사용하면 컬럼별로 다른 연산 가능
cctv_group = cctv[['동이름',"위도","경도","카메라대수"]].groupby("동이름",as_index=False).agg({"카메라대수":"sum",
                                                    "위도":"mean","경도":"mean"})

# %%
dong_group = dong[["동이름","인구(명)",'공무원(명)']].groupby('동이름',as_index=False).sum()
dong_group
# Out:
#     동이름   인구(명)  공무원(명)
# 0   건국동   22423      16
# 1   계림동   20827      28
# 2   광산구  404221     341
# 3   광천동    8084      15
# 4   금호동   48584      35
# ..  ...     ...     ...
# 68  하남동   26266      17
# 69   학동    7724      13
# 70  학운동   11445      14
# 71  화정동   61642      61
# 72  효덕동   16133      13
#
# [73 rows x 3 columns]

# %%
# 두 데이터 병함
final = pd.merge(cctv_group, dong_group, how="inner", on="동이름")
final
# Out:
#     동이름  카메라대수         위도          경도  인구(명)  공무원(명)
# 0   건국동      2  35.215098  126.880692  22423      16
# 1   계림동    163  37.176593  124.902740  20827      28
# 2   광천동     79  35.165186  126.880207   8084      15
# 3   금호동    182  35.132212  126.857730  48584      35
# 4   농성동    198  35.153344  126.890065  15908      31
# 5   대촌동      3  35.230968  126.863477   6305      14
# 6   도산동    124  35.130103  126.792174  15279      17
# 7   동림동     71  35.185267  126.856603  23375      15
# 8   동명동     65  35.150985  126.924681   3890      12
# 9   동천동     62  35.170229  126.862898  16245      16
# 10  두암동    310  36.190123  125.912769  37210      46
# 11  매곡동     65  35.224447  126.854180  13842      13
# 12  문흥동    209  35.184207  126.922044  31690      29
# 13  방림동     71  39.304071  122.746825  15553      23
# 14  백운동    147  35.136385  126.903389  18581      24
# 15  봉선동    241  35.127008  126.910780  42266      28
# 16  비아동     86  35.222563  126.823287   7481      13
# 17  산수동    212  38.048547  124.032972  19080      28
# 18  삼각동     90  35.199437  126.900773  14116      13
# 19  삼도동      3  35.128083  126.682771   2199      12
# 20  서창동     15  35.108261  126.824437   5792      14
# 21  송정동    153  35.139005  126.799946  17421      27
# 22  수완동    146  35.193015  126.826985  77438      27
# 23  신가동    155  36.288416  125.727722  18457      17
# 24  신안동     91  35.168812  126.900913  12379      14
# 25  신용동     73  41.124764  120.949800  29953      17
# 26  신창동    169  35.192479  126.840553  34988      20
# 27   양동    111  46.226897  115.823289   8264      28
# 28  양림동     96  35.138630  126.915229   7018      12
# 29  양산동    122  35.206861  126.873261  37958      18
# 30  오치동    173  37.118288  124.976993  23463      30
# 31  용봉동    212  35.178992  126.901708  38542      19
# 32  우산동    266  35.164409  126.856850  39195      40
# 33  운남동    121  35.183006  126.819193  30856      19
# 34  운암동    231  35.175241  126.879818  44052      43
# 35  월곡동    194  35.170627  126.810443  26478      32
# 36  월산동    278  37.030213  125.009879  23728      37
# 37  유덕동      2  35.164947  126.851836  10975      14
# 38  일곡동    132  35.208288  126.895221  29944      17
# 39  임곡동     17  35.218320  126.745065   2139      12
# 40   임동    108  35.164880  126.894853   9157      12
# 41  주월동    217  38.438984  123.587785  29943      26
# 42  중흥동    230  39.716408  122.362972  16460      34
# 43  지산동    112  35.147779  126.931230  23990      29
# 44  지원동      4  35.130245  126.931444   8816      28
# 45  진월동    144  35.117355  125.922220  29383      14
# 46  치평동    201  35.152759  126.848064  30293      21
# 47  풍암동    184  38.343213  123.655146  36781      19
# 48  풍향동     51  35.164899  126.925985   5738      12
# 49  하남동     93  35.179969  126.800276  26266      17
# 50   학동     70  35.134848  126.927965   7724      13
# 51  화정동    321  35.144983  126.876487  61642      61

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\ghaischool\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\ghaischool\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\ghaischool\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in c:\users\ghaischool\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ghaischool\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ghaischool\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ghaischool\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ghaischool\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghaischool\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghaischool\anaconda3\lib\site-packages (from requests->folium) (3.4)

# %%
import folium
m = folium.Map(location=[35.1595454, 126.8526012], zoom_start=12)

folium.Marker(
    [35.1595454, 126.8526012], popup="<i>광주</i>", tooltip="클릭해보세요",
).add_to(m)


folium.CircleMarker(
    location=[35.1595454, 126.8526012],
    radius=50,
    popup="광주광역시",
    color="#3186cc",
    fill=True,
    fill_color="#3186cc",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a051a8b2e8e946eea8cb179d36c38432 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a051a8b2e8e946eea8cb179d36c38432&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a051a8b2e8e946eea8cb179d36c38432 = L.map(
#                 &quot;map_a051a8b2e8e946eea8cb179d36c38432&quot;,
#                 {
#                     center: [35.1595454, 126.8526012],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b0e047ad06104d6a15a6f26dd6184d1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a051a8b2e8e946eea8cb179d36c38432);
#
#
#             var marker_30cac40314f2bfd4ffcae8dceea38d8e = L.marker(
#                 [35.1595454, 126.8526012],
#                 {}
#             ).addTo(map_a051a8b2e8e946eea8cb179d36c38432);
#
#
#         var popup_b9fab6428937c39c066e4a058daf2984 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_083c897b07f2c624676f6108bde90c01 = $(`&lt;div id=&quot;html_083c897b07f2c624676f6108bde90c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;광주&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_b9fab6428937c39c066e4a058daf2984.setContent(html_083c897b07f2c624676f6108bde90c01);
#
#
#
#         marker_30cac40314f2bfd4ffcae8dceea38d8e.bindPopup(popup_b9fab6428937c39c066e4a058daf2984)
#         ;
#
#
#
#
#             marker_30cac40314f2bfd4ffcae8dceea38d8e.bindTooltip(
#                 `&lt;div&gt;
#                      클릭해보세요
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_039c7eb5207670d8bc11254bea5a1116 = L.circleMarker(
#                 [35.1595454, 126.8526012],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a051a8b2e8e946eea8cb179d36c38432);
#
#
#         var popup_55c51264de5f9a9725d4f6ade20f883a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cdfa3d865a232ccfcc583e7415dc78a = $(`&lt;div id=&quot;html_5cdfa3d865a232ccfcc583e7415dc78a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시&lt;/div&gt;`)[0];
#                 popup_55c51264de5f9a9725d4f6ade20f883a.setContent(html_5cdfa3d865a232ccfcc583e7415dc78a);
#
#
#
#         circle_marker_039c7eb5207670d8bc11254bea5a1116.bindPopup(popup_55c51264de5f9a9725d4f6ade20f883a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import MarkerCluster

# %%
m = folium.Map(location=[35.1595454, 126.8526012], zoom_start=12)

# 마커들을 군집시켜 시각화해주는 플러그인 추가
marker_cluster = MarkerCluster().add_to(m)

for n, c, lat, long, in zip(final['동이름'],final['카메라대수'],final['위도'],final['경도']) :
    folium.Marker([lat,long],
                 tooltip=n+":"+str(c)+"대").add_to(marker_cluster)
    
m.save("index.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_964561150d841660b320464a243583ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_964561150d841660b320464a243583ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_964561150d841660b320464a243583ec = L.map(
#                 &quot;map_964561150d841660b320464a243583ec&quot;,
#                 {
#                     center: [35.1595454, 126.8526012],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_149081e48aea3a9b2d2240faa7588faf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_964561150d841660b320464a243583ec);
#
#
#             var marker_cluster_5f081945467ab099dc492629bb87c10c = L.markerClusterGroup(
#                 {}
#             );
#             map_964561150d841660b320464a243583ec.addLayer(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             var marker_434a586807647c35d9ba4f8579667096 = L.marker(
#                 [35.21509806, 126.8806923],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_434a586807647c35d9ba4f8579667096.bindTooltip(
#                 `&lt;div&gt;
#                      건국동:2대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6d7db94b8b1b19b5e5820b1e74fdd62b = L.marker(
#                 [37.176593065384615, 124.90274015274726],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_6d7db94b8b1b19b5e5820b1e74fdd62b.bindTooltip(
#                 `&lt;div&gt;
#                      계림동:163대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_70ff4bb7483ce6a62207145a5fd4f06b = L.marker(
#                 [35.165185843148144, 126.8802074037037],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_70ff4bb7483ce6a62207145a5fd4f06b.bindTooltip(
#                 `&lt;div&gt;
#                      광천동:79대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a96d9e1b28f0abfdc4838d968372247c = L.marker(
#                 [35.1322118081982, 126.85772995045045],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_a96d9e1b28f0abfdc4838d968372247c.bindTooltip(
#                 `&lt;div&gt;
#                      금호동:182대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c7b8b0390d88cce4f31c99b4471227aa = L.marker(
#                 [35.153343906857145, 126.89006499714286],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_c7b8b0390d88cce4f31c99b4471227aa.bindTooltip(
#                 `&lt;div&gt;
#                      농성동:198대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4df3ad457f601f13349295173bceec51 = L.marker(
#                 [35.230968, 126.863477],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_4df3ad457f601f13349295173bceec51.bindTooltip(
#                 `&lt;div&gt;
#                      대촌동:3대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b864971b76d6c7d90eea4fd8904278a8 = L.marker(
#                 [35.130103433174604, 126.79217396666667],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);
#
#
#             marker_b864971b76d6c7d90eea4fd8904278a8.bindTooltip(
#                 `&lt;div&gt;
#                      도산동:124대
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9d420e8bbbd3a1253b320cb92c1c353 = L.marker(
#                 [35.185267161707316, 126.85660313414634],
#                 {}
#             ).addTo(marker_cluster_5f081945467ab099dc492629bb87c10c);

# %%
matplotlib
